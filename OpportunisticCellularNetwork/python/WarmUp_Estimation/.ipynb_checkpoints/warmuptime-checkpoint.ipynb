# %%
import sys
import numpy as np
import pandas as pd
import matplotlib as mpl 
import scipy.stats as st
import matplotlib.pyplot as plt

path = './'
rate = [25]
csv_name = './warmuptime'
times     = []

def main():

    
        for l in range(0,len(rate)):

            for rep in range(0,len(run)):

                warm_up_i = 0
                cellular  = '' 

                # parse csv
                raw = pd.read_csv(path + csv_name + '.csv')

                # compute vector of mean values     
                vec_mean_cell = [[],[],[],[],[],[],[],[],[],[]]

                for j in range(0,10):

                    vec_mean_cell[j] = []

                    times = raw[raw.columns[2*j]]
                    array = raw[raw.columns[2*j+1]]   

                    for i in range(0,len(array)):
                        temp = array[0:i]
                        vec_mean_cell[j].append(np.mean(temp))

                    plt.plot(times, vec_mean_cell[j], label=raw.columns[2*j]) 
                    
                    if j == 9:
                        plt.title('Mean Throughput as a function of time - RUN #' + str(run))
                        plt.grid(True)
                        plt.xlabel('time [s]')
                        plt.ylabel('E[THR](t) [#packets/timeslot]')
                        plt.legend()
                        plt.show()
            
            global_std      = []
            warm_up_time    = 0
            simulation_time = 10
            
            for i in range(0, len(times)):
                
                global_mean_j = []
                
                for j in range(0, 10):
                    global_mean_j.append(vec_mean_cell[j][i])
                    
                global_std.append(np.std(global_mean_j))
                
                if global_std[i-1] - global_std[i] >= 0.1:
                    warmup_time = times[i]
                    
                if global_std[i-1] - global_std[i] >= 0.01:
                    simulation_time = times[i]
                
            plt.plot(times, global_std)
            plt.show()
            print("WARM UP TIME: " + str(warm_up_time))
            print("SIMULATION TIME: " + str(simulation_time))

if __name__ == '__main__':
    main()
# Out:
# 0.728
